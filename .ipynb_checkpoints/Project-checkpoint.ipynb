# %%
import os
import glob
from sklearn.model_selection import train_test_split
from mido import MidiFile
import pretty_midi
import IPython.display
from midi2audio import FluidSynth
import numpy as np
import matplotlib.pyplot as plt

# %%
genres = ["funk", "jazz", "rock", "latin", "hiphop"]

# %%
files = []
labels = []
for i, genre in enumerate(genres):
    for file in glob.glob(r'C:\Users\nooro\Documents\Robotikk\MCT4052\MCT_4052_Project\data\drummer*\session*\*%s*.mid'%genre, recursive=True):
        files.append(file)
        labels.append(i)


#Split data into training, validation and testing sets
tr_data, test_data, tr_labels, test_labels = train_test_split(files, labels, test_size=0.2, random_state=42)
print("All files:", len(files))
print(f"Training set: {len(tr_data)}, testing set: {len(test_data)}")
# Out:
# All files: 868
# Training set: 694, testing set: 174

# %% [markdown]
# <h2>Preprocessing</h2>
#
# Here we change the pitch values of each recording to lower the amount of features used and reduce redundancy, as well as simplifying reading and understanding the results of the project, the reasoning for these exact changes are discussed in the "Learning to Groove" paper, accompanying the dataset.

# %%
def convert_to_simple(list, pitch, convert_from, convert_to):
    if pitch in convert_from:
        list.append(convert_to)
    return list
def feature_extraction(input):
    #These are the pitches representing the main groups of drum instruments used in the project (bass, snare, hi-hat, etc...)
    pitch_values = [36, 38, 50, 47, 43, 46, 42, 49, 51]
    pitches_list = []
    for data in input:
        mid = pretty_midi.PrettyMIDI(data)
        instrument = mid.instruments[0]
        simple_pitches = []
        for note in instrument.notes:
            pitch = note.pitch
            simple_pitches = convert_to_simple(simple_pitches, pitch, [36], 36)
            simple_pitches = convert_to_simple(simple_pitches, pitch, [37, 38, 40], 38)
            simple_pitches = convert_to_simple(simple_pitches, pitch, [48, 50], 50)
            simple_pitches = convert_to_simple(simple_pitches, pitch, [45, 47], 47)
            simple_pitches = convert_to_simple(simple_pitches, pitch, [43, 58], 43)
            simple_pitches = convert_to_simple(simple_pitches, pitch, [26, 46], 46)
            simple_pitches = convert_to_simple(simple_pitches, pitch, [22, 42, 44], 42)
            simple_pitches = convert_to_simple(simple_pitches, pitch, [49, 52, 55, 57], 49)
            simple_pitches = convert_to_simple(simple_pitches, pitch, [51, 53, 59], 51)

        if len(simple_pitches) != len(instrument.notes):
            print("This midi file contains missing notes!", data)
        pitches_list.append(simple_pitches)
    pitch_frequency = [] #Frequency refers to amount of occurences, not audio frequency
    for pitches in pitches_list:
        freq = []
        for i in range(len(pitch_values)):
            freq.append(0)
        for pitch in pitches:
            for i in range(len(pitch_values)):
                if pitch == pitch_values[i]:
                    freq[i] += 1
        pitch_frequency.append(freq)
    return pitch_frequency

# %%
tr_features = feature_extraction(tr_data)
test_features = feature_extraction(test_data)

# %% [markdown]
# <h2>Training phase

# %%
from sklearn.neural_network import MLPClassifier
from sklearn import metrics

##Creating an instance of a MLP classifier
#and setting it some option (max mum epoch, verbose on, activation of neurons)
mlp = MLPClassifier(hidden_layer_sizes=(10,5), max_iter=2000, activation='relu', verbose=True)

#train the model
mlp.fit(tr_features, tr_labels)
# Out:
# Iteration 1, loss = 8.81332372
# Iteration 2, loss = 8.44425760
# Iteration 3, loss = 8.23405195
# Iteration 4, loss = 8.02183578
# Iteration 5, loss = 7.82787262
# Iteration 6, loss = 7.58856105
# Iteration 7, loss = 7.36171360
# Iteration 8, loss = 7.11350545
# Iteration 9, loss = 6.83955761
# Iteration 10, loss = 6.58588927
# Iteration 11, loss = 6.36345452
# Iteration 12, loss = 6.11175899
# Iteration 13, loss = 5.94302352
# Iteration 14, loss = 5.76179493
# Iteration 15, loss = 5.62702856
# Iteration 16, loss = 5.52521483
# Iteration 17, loss = 5.38663700
# Iteration 18, loss = 5.22421081
# Iteration 19, loss = 5.02218560
# Iteration 20, loss = 4.83446014
# Iteration 21, loss = 4.59444063
# Iteration 22, loss = 4.40637500
# Iteration 23, loss = 4.22443663
# Iteration 24, loss = 4.10946134
# Iteration 25, loss = 4.06477673
# Iteration 26, loss = 4.00180829
# Iteration 27, loss = 3.95592110
# Iteration 28, loss = 3.91863212
# Iteration 29, loss = 3.90010124
# Iteration 30, loss = 3.87001794
# Iteration 31, loss = 3.83347069
# Iteration 32, loss = 3.81572298
# Iteration 33, loss = 3.79480941
# Iteration 34, loss = 3.76673842
# Iteration 35, loss = 3.72823641
# Iteration 36, loss = 3.70006188
# Iteration 37, loss = 3.68779226
# Iteration 38, loss = 3.69034210
# Iteration 39, loss = 3.65237984
# Iteration 40, loss = 3.62718641
# Iteration 41, loss = 3.59619039
# Iteration 42, loss = 3.56845630
# Iteration 43, loss = 3.54673748
# Iteration 44, loss = 3.52021324
# Iteration 45, loss = 3.49956086
# Iteration 46, loss = 3.47752385
# Iteration 47, loss = 3.45273170
# Iteration 48, loss = 3.44078064
# Iteration 49, loss = 3.40382074
# Iteration 50, loss = 3.39050680
# Iteration 51, loss = 3.35593761
# Iteration 52, loss = 3.32002780
# Iteration 53, loss = 3.29809489
# Iteration 54, loss = 3.27517858
# Iteration 55, loss = 3.25906383
# Iteration 56, loss = 3.24841371
# Iteration 57, loss = 3.21187253
# Iteration 58, loss = 3.18876744
# Iteration 59, loss = 3.16382995
# Iteration 60, loss = 3.14283953
# Iteration 61, loss = 3.12786245
# Iteration 62, loss = 3.09754365
# Iteration 63, loss = 3.06830902
# Iteration 64, loss = 3.04579862
# Iteration 65, loss = 3.01646231
# Iteration 66, loss = 2.99330377
# Iteration 67, loss = 2.97547495
# Iteration 68, loss = 2.95531560
# Iteration 69, loss = 2.92592443
# Iteration 70, loss = 2.90817967
# Iteration 71, loss = 2.88139997
# Iteration 72, loss = 2.85241126
# Iteration 73, loss = 2.82080597
# Iteration 74, loss = 2.81994613
# Iteration 75, loss = 2.77826267
# Iteration 76, loss = 2.76424324
# Iteration 77, loss = 2.76130545
# Iteration 78, loss = 2.74333533
# Iteration 79, loss = 2.70326760
# Iteration 80, loss = 2.68044699
# Iteration 81, loss = 2.66349938
# Iteration 82, loss = 2.64962480
# Iteration 83, loss = 2.62463997
# Iteration 84, loss = 2.62642751
# Iteration 85, loss = 2.57492756
# Iteration 86, loss = 2.56559494
# Iteration 87, loss = 2.53641270
# Iteration 88, loss = 2.55013193
# Iteration 89, loss = 2.49729287
# Iteration 90, loss = 2.48032516
# Iteration 91, loss = 2.48723174
# Iteration 92, loss = 2.46818995
# Iteration 93, loss = 2.44475712
# Iteration 94, loss = 2.43860101
# Iteration 95, loss = 2.41261276
# Iteration 96, loss = 2.41264587
# Iteration 97, loss = 2.37102834
# Iteration 98, loss = 2.37986031
# Iteration 99, loss = 2.33214018
# Iteration 100, loss = 2.34538754
# Iteration 101, loss = 2.31434674
# Iteration 102, loss = 2.31515998
# Iteration 103, loss = 2.28841048
# Iteration 104, loss = 2.26342662
# Iteration 105, loss = 2.24186585
# Iteration 106, loss = 2.23881243
# Iteration 107, loss = 2.23618327
# Iteration 108, loss = 2.20388396
# Iteration 109, loss = 2.19119858
# Iteration 110, loss = 2.17370890
# Iteration 111, loss = 2.16248699
# Iteration 112, loss = 2.13532659
# Iteration 113, loss = 2.13757412
# Iteration 114, loss = 2.10105210
# Iteration 115, loss = 2.08405579
# Iteration 116, loss = 2.08058610
# Iteration 117, loss = 2.06600612
# Iteration 118, loss = 2.04951222
# Iteration 119, loss = 2.05858334
# Iteration 120, loss = 2.03034359
# Iteration 121, loss = 2.03619547
# Iteration 122, loss = 2.01399206
# Iteration 123, loss = 2.01731065
# Iteration 124, loss = 1.99277906
# Iteration 125, loss = 1.97865397
# Iteration 126, loss = 1.96512329
# Iteration 127, loss = 1.95466621
# Iteration 128, loss = 1.94227588
# Iteration 129, loss = 1.93004679
# Iteration 130, loss = 1.93114817
# Iteration 131, loss = 1.90702669
# Iteration 132, loss = 1.90423596
# Iteration 133, loss = 1.89458810
# Iteration 134, loss = 1.88342214
# Iteration 135, loss = 1.87622945
# Iteration 136, loss = 1.86866159
# Iteration 137, loss = 1.85245725
# Iteration 138, loss = 1.85071743
# Iteration 139, loss = 1.83537227
# Iteration 140, loss = 1.82197319
# Iteration 141, loss = 1.82816534
# Iteration 142, loss = 1.81391766
# Iteration 143, loss = 1.80322673
# Iteration 144, loss = 1.79885216
# Iteration 145, loss = 1.80509551
# Iteration 146, loss = 1.78082808
# Iteration 147, loss = 1.78008224
# Iteration 148, loss = 1.78761158
# Iteration 149, loss = 1.76034935
# Iteration 150, loss = 1.77987022
# Iteration 151, loss = 1.75036927
# Iteration 152, loss = 1.76934957
# Iteration 153, loss = 1.75804906
# Iteration 154, loss = 1.74238122
# Iteration 155, loss = 1.76539487
# Iteration 156, loss = 1.73751263
# Iteration 157, loss = 1.73371242
# Iteration 158, loss = 1.71441033
# Iteration 159, loss = 1.72417524
# Iteration 160, loss = 1.70196521
# Iteration 161, loss = 1.71374445
# Iteration 162, loss = 1.69240652
# Iteration 163, loss = 1.69648496
# Iteration 164, loss = 1.69084483
# Iteration 165, loss = 1.68207010
# Iteration 166, loss = 1.68623829
# Iteration 167, loss = 1.68339717
# Iteration 168, loss = 1.69163313
# Iteration 169, loss = 1.68269373
# Iteration 170, loss = 1.66928826
# Iteration 171, loss = 1.66618478
# Iteration 172, loss = 1.65944899
# Iteration 173, loss = 1.66522046
# Iteration 174, loss = 1.66089449
# Iteration 175, loss = 1.65665155
# Iteration 176, loss = 1.64840528
# Iteration 177, loss = 1.64981715
# Iteration 178, loss = 1.64049450
# Iteration 179, loss = 1.63519789
# Iteration 180, loss = 1.63658946
# Iteration 181, loss = 1.63287837
# Iteration 182, loss = 1.62700733
# Iteration 183, loss = 1.63241404
# Iteration 184, loss = 1.62138579
# Iteration 185, loss = 1.62600802
# Iteration 186, loss = 1.62141073
# Iteration 187, loss = 1.62404227
# Iteration 188, loss = 1.64408810
# Iteration 189, loss = 1.65754452
# Iteration 190, loss = 1.61164976
# Iteration 191, loss = 1.66912496
# Iteration 192, loss = 1.64698261
# Iteration 193, loss = 1.62835920
# Iteration 194, loss = 1.60207830
# Iteration 195, loss = 1.61023848
# Iteration 196, loss = 1.60208306
# Iteration 197, loss = 1.59048052
# Iteration 198, loss = 1.60007531
# Iteration 199, loss = 1.58218912
# Iteration 200, loss = 1.58715541
# Iteration 201, loss = 1.58886741
# Iteration 202, loss = 1.58015333
# Iteration 203, loss = 1.59423926
# Iteration 204, loss = 1.57968903
# Iteration 205, loss = 1.57613045
# Iteration 206, loss = 1.57727915
# Iteration 207, loss = 1.57830272
# Iteration 208, loss = 1.57402697
# Iteration 209, loss = 1.56752737
# Iteration 210, loss = 1.57529707
# Iteration 211, loss = 1.56773576
# Iteration 212, loss = 1.55266869
# Iteration 213, loss = 1.56741424
# Iteration 214, loss = 1.55585832
# Iteration 215, loss = 1.57251956
# Iteration 216, loss = 1.56782342
# Iteration 217, loss = 1.55588173
# Iteration 218, loss = 1.56477907
# Iteration 219, loss = 1.54485351
# Iteration 220, loss = 1.55192149
# Iteration 221, loss = 1.54867841
# Iteration 222, loss = 1.55407815
# Iteration 223, loss = 1.53565907
# Iteration 224, loss = 1.54357634
# Iteration 225, loss = 1.54659651
# Iteration 226, loss = 1.53768555
# Iteration 227, loss = 1.53072052
# Iteration 228, loss = 1.55451656
# Iteration 229, loss = 1.52899934
# Iteration 230, loss = 1.53518609
# Iteration 231, loss = 1.53528719
# Iteration 232, loss = 1.53797234
# Iteration 233, loss = 1.51991734
# Iteration 234, loss = 1.53143613
# Iteration 235, loss = 1.51886681
# Iteration 236, loss = 1.51666137
# Iteration 237, loss = 1.51321597
# Iteration 238, loss = 1.51014299
# Iteration 239, loss = 1.52251818
# Iteration 240, loss = 1.50550215
# Iteration 241, loss = 1.50971738
# Iteration 242, loss = 1.50858904
# Iteration 243, loss = 1.50597763
# Iteration 244, loss = 1.51352787
# Iteration 245, loss = 1.49627488
# Iteration 246, loss = 1.51071542
# Iteration 247, loss = 1.50384498
# Iteration 248, loss = 1.50540944
# Iteration 249, loss = 1.49656425
# Iteration 250, loss = 1.50284376
# Iteration 251, loss = 1.49791619
# Iteration 252, loss = 1.49076198
# Iteration 253, loss = 1.48669035
# Iteration 254, loss = 1.48988249
# Iteration 255, loss = 1.48576639
# Iteration 256, loss = 1.48268441
# Iteration 257, loss = 1.47626277
# Iteration 258, loss = 1.48291806
# Iteration 259, loss = 1.47875665
# Iteration 260, loss = 1.47248594
# Iteration 261, loss = 1.47695567
# Iteration 262, loss = 1.47202274
# Iteration 263, loss = 1.47077409
# Iteration 264, loss = 1.46896860
# Iteration 265, loss = 1.47008452
# Iteration 266, loss = 1.46998249
# Iteration 267, loss = 1.46687869
# Iteration 268, loss = 1.46110194
# Iteration 269, loss = 1.46302370
# Iteration 270, loss = 1.45861209
# Iteration 271, loss = 1.45985260
# Iteration 272, loss = 1.45615333
# Iteration 273, loss = 1.45721267
# Iteration 274, loss = 1.45197518
# Iteration 275, loss = 1.45192285
# Iteration 276, loss = 1.45513533
# Iteration 277, loss = 1.45380630
# Iteration 278, loss = 1.44962031
# Iteration 279, loss = 1.44725259
# Iteration 280, loss = 1.44421262
# Iteration 281, loss = 1.44560234
# Iteration 282, loss = 1.44569417
# Iteration 283, loss = 1.44685947
# Iteration 284, loss = 1.44586715
# Iteration 285, loss = 1.44502744
# Iteration 286, loss = 1.45762936
# Iteration 287, loss = 1.44289951
# Iteration 288, loss = 1.44999835
# Iteration 289, loss = 1.44411358
# Iteration 290, loss = 1.44572502
# Iteration 291, loss = 1.44351814
# Iteration 292, loss = 1.43688935
# Iteration 293, loss = 1.45436325
# Iteration 294, loss = 1.44344411
# Iteration 295, loss = 1.43475221
# Iteration 296, loss = 1.44544496
# Iteration 297, loss = 1.42906294
# Iteration 298, loss = 1.42685266
# Iteration 299, loss = 1.42702187
# Iteration 300, loss = 1.42879673
# Iteration 301, loss = 1.42472898
# Iteration 302, loss = 1.42656027
# Iteration 303, loss = 1.42045075
# Iteration 304, loss = 1.42492199
# Iteration 305, loss = 1.42354086
# Iteration 306, loss = 1.41607184
# Iteration 307, loss = 1.42373045
# Iteration 308, loss = 1.41949455
# Iteration 309, loss = 1.41810463
# Iteration 310, loss = 1.41674302
# Iteration 311, loss = 1.41696003
# Iteration 312, loss = 1.42211073
# Iteration 313, loss = 1.40958884
# Iteration 314, loss = 1.42263729
# Iteration 315, loss = 1.42014106
# Iteration 316, loss = 1.41683258
# Iteration 317, loss = 1.42338358
# Iteration 318, loss = 1.41884970
# Iteration 319, loss = 1.41286503
# Iteration 320, loss = 1.40753363
# Iteration 321, loss = 1.41552091
# Iteration 322, loss = 1.40530869
# Iteration 323, loss = 1.40730787
# Iteration 324, loss = 1.40677411
# Iteration 325, loss = 1.41784722
# Iteration 326, loss = 1.41339441
# Iteration 327, loss = 1.40370856
# Iteration 328, loss = 1.40832305
# Iteration 329, loss = 1.40880261
# Iteration 330, loss = 1.40789254
# Iteration 331, loss = 1.40093683
# Iteration 332, loss = 1.40138170
# Iteration 333, loss = 1.39993178
# Iteration 334, loss = 1.39625403
# Iteration 335, loss = 1.39906332
# Iteration 336, loss = 1.39358312
# Iteration 337, loss = 1.39472792
# Iteration 338, loss = 1.39150784
# Iteration 339, loss = 1.39830429
# Iteration 340, loss = 1.42076288
# Iteration 341, loss = 1.42325786
# Iteration 342, loss = 1.39469272
# Iteration 343, loss = 1.39811935
# Iteration 344, loss = 1.40602607
# Iteration 345, loss = 1.41482149
# Iteration 346, loss = 1.39776194
# Iteration 347, loss = 1.39908945
# Iteration 348, loss = 1.39550116
# Iteration 349, loss = 1.39092397
# Iteration 350, loss = 1.38682441
# Iteration 351, loss = 1.39703903
# Iteration 352, loss = 1.39499904
# Iteration 353, loss = 1.39806219
# Iteration 354, loss = 1.38186182
# Iteration 355, loss = 1.40203417
# Iteration 356, loss = 1.39350710
# Iteration 357, loss = 1.38708047
# Iteration 358, loss = 1.37544349
# Iteration 359, loss = 1.39093251
# Iteration 360, loss = 1.38445978
# Iteration 361, loss = 1.38069911
# Iteration 362, loss = 1.37689616
# Iteration 363, loss = 1.37809360
# Iteration 364, loss = 1.37601276
# Iteration 365, loss = 1.38004282
# Iteration 366, loss = 1.37728405
# Iteration 367, loss = 1.37488178
# Iteration 368, loss = 1.37736595
# Iteration 369, loss = 1.37339730
# Iteration 370, loss = 1.37412296
# Iteration 371, loss = 1.37249900
# Iteration 372, loss = 1.37975671
# Iteration 373, loss = 1.37034457
# Iteration 374, loss = 1.37559616
# Iteration 375, loss = 1.37627244
# Iteration 376, loss = 1.37026713
# Iteration 377, loss = 1.36495424
# Iteration 378, loss = 1.38212428
# Iteration 379, loss = 1.37096884
# Iteration 380, loss = 1.36520233
# Iteration 381, loss = 1.36830093
# Iteration 382, loss = 1.37132628
# Iteration 383, loss = 1.37033572
# Iteration 384, loss = 1.36428402
# Iteration 385, loss = 1.36606506
# Iteration 386, loss = 1.37128279
# Iteration 387, loss = 1.36123834
# Iteration 388, loss = 1.35844291
# Iteration 389, loss = 1.35998295
# Iteration 390, loss = 1.37432858
# Iteration 391, loss = 1.37120406
# Iteration 392, loss = 1.35641699
# Iteration 393, loss = 1.36851081
# Iteration 394, loss = 1.35730633
# Iteration 395, loss = 1.36542649
# Iteration 396, loss = 1.35850238
# Iteration 397, loss = 1.36656830
# Iteration 398, loss = 1.36467499
# Iteration 399, loss = 1.36905345
# Iteration 400, loss = 1.37037046
# Iteration 401, loss = 1.35909288
# Iteration 402, loss = 1.35423595
# Iteration 403, loss = 1.35482678
# Iteration 404, loss = 1.36180201
# Iteration 405, loss = 1.35775330
# Iteration 406, loss = 1.35104224
# Iteration 407, loss = 1.35371325
# Iteration 408, loss = 1.34937175
# Iteration 409, loss = 1.35736865
# Iteration 410, loss = 1.35246767
# Iteration 411, loss = 1.35556172
# Iteration 412, loss = 1.35034658
# Iteration 413, loss = 1.34710288
# Iteration 414, loss = 1.35370657
# Iteration 415, loss = 1.36191702
# Iteration 416, loss = 1.35203064
# Iteration 417, loss = 1.35264064
# Iteration 418, loss = 1.35606319
# Iteration 419, loss = 1.34639188
# Iteration 420, loss = 1.35300435
# Iteration 421, loss = 1.36062832
# Iteration 422, loss = 1.34971581
# Iteration 423, loss = 1.34398974
# Iteration 424, loss = 1.34950851
# Iteration 425, loss = 1.34549614
# Iteration 426, loss = 1.34392624
# Iteration 427, loss = 1.34306452
# Iteration 428, loss = 1.34055911
# Iteration 429, loss = 1.34121489
# Iteration 430, loss = 1.34481272
# Iteration 431, loss = 1.33858317
# Iteration 432, loss = 1.34490287
# Iteration 433, loss = 1.34935857
# Iteration 434, loss = 1.34005193
# Iteration 435, loss = 1.34455017
# Iteration 436, loss = 1.34051737
# Iteration 437, loss = 1.33964293
# Iteration 438, loss = 1.35571004
# Iteration 439, loss = 1.34722390
# Iteration 440, loss = 1.33710583
# Iteration 441, loss = 1.34201245
# Iteration 442, loss = 1.33769435
# Iteration 443, loss = 1.33985870
# Iteration 444, loss = 1.33999250
# Iteration 445, loss = 1.33570121
# Iteration 446, loss = 1.33841230
# Iteration 447, loss = 1.33837243
# Iteration 448, loss = 1.33755567
# Iteration 449, loss = 1.33687059
# Iteration 450, loss = 1.33545725
# Iteration 451, loss = 1.33800986
# Iteration 452, loss = 1.33854422
# Iteration 453, loss = 1.33493248
# Iteration 454, loss = 1.34296076
# Iteration 455, loss = 1.34458589
# Iteration 456, loss = 1.34118317
# Iteration 457, loss = 1.33422068
# Iteration 458, loss = 1.33433961
# Iteration 459, loss = 1.33983089
# Iteration 460, loss = 1.33465110
# Iteration 461, loss = 1.32966213
# Iteration 462, loss = 1.33407517
# Iteration 463, loss = 1.33332461
# Iteration 464, loss = 1.33229403
# Iteration 465, loss = 1.32945549
# Iteration 466, loss = 1.32667193
# Iteration 467, loss = 1.32721971
# Iteration 468, loss = 1.32890449
# Iteration 469, loss = 1.33065985
# Iteration 470, loss = 1.32748709
# Iteration 471, loss = 1.32713471
# Iteration 472, loss = 1.32754641
# Iteration 473, loss = 1.32626382
# Iteration 474, loss = 1.33100764
# Iteration 475, loss = 1.32588802
# Iteration 476, loss = 1.32623867
# Iteration 477, loss = 1.32519009
# Iteration 478, loss = 1.33291070
# Iteration 479, loss = 1.34496080
# Iteration 480, loss = 1.32794049
# Iteration 481, loss = 1.33526565
# Iteration 482, loss = 1.34340828
# Iteration 483, loss = 1.34214000
# Iteration 484, loss = 1.33103148
# Iteration 485, loss = 1.33855418
# Iteration 486, loss = 1.33071228
# Iteration 487, loss = 1.31705292
# Iteration 488, loss = 1.32794313
# Iteration 489, loss = 1.32721995
# Iteration 490, loss = 1.32280363
# Iteration 491, loss = 1.32157998
# Iteration 492, loss = 1.32507328
# Iteration 493, loss = 1.32162090
# Iteration 494, loss = 1.32832939
# Iteration 495, loss = 1.34268026
# Iteration 496, loss = 1.32664173
# Iteration 497, loss = 1.32991664
# Iteration 498, loss = 1.32407930
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=(10, 5), max_iter=2000, verbose=True)

# %%
#applying the the model on the test data (features)
pred_labels = mlp.predict(test_features)

# %%
print("Accuracy is", metrics.accuracy_score(test_labels, pred_labels))
print()
print(metrics.classification_report(test_labels, pred_labels))
# Out:
# Accuracy is 0.41954022988505746
#
#               precision    recall  f1-score   support
#
#            0       0.23      0.16      0.19        43
#            1       0.25      0.04      0.07        23
#            2       0.45      0.84      0.59        70
#            3       0.83      0.24      0.37        21
#            4       0.50      0.06      0.11        17
#
#     accuracy                           0.42       174
#    macro avg       0.45      0.27      0.27       174
# weighted avg       0.42      0.42      0.35       174

# %% [markdown]
# Looking at these results we see that the training actually isn't too bad considering the very simple features used. As the accuracy is over 20% its a lot better than guessing, but of course not good enough yet. Moving forward, I will be adding more relevant features to the training, and trying different genres to train on.
